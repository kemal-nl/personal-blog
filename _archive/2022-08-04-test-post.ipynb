# %% [markdown]
# # Fastpages Notebook Blog Post
# > Just trying out some stuff.
#
# - toc: true
# - badges: false
# - comments: true
# - categories: [jupyter, test_category]
# - image: images/chart-preview.png

# %% [markdown]
# # Introduction
# Just introducing some things here.

# %%
for i in ['a', 'b', 'c']:
    print(i)
# Out:
# a
# b
# c

# %% [markdown]
# What a great result!

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.arange(10)
y = random.sample(range(10), 10)

plt.plot(x, y)
plt.title('Plotting random numbers in a line chart')
# Out:
# Text(0.5, 1.0, 'Plotting random numbers in a line chart')

# %% [markdown]
# # Conclusion
# Thank you and bye!
